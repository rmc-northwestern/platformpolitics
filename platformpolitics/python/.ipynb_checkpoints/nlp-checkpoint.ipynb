# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import GaussianNB, MultinomialNB, ComplementNB
import numpy as np
import os, pickle


labels = []
users = []

test_labels = []
test_users = []

basedir = "TXSen"

#create labels and list of file paths, ignore non .txt
for folder in os.listdir(basedir):
    print(basedir + '/' + folder)
    for filename in os.listdir(basedir + '/' + folder)[:1000]:
        if filename.endswith(".txt"):
            labels.append(folder)
            users.append(basedir + '/' + folder + '/' + filename)
        else:
            continue
    #the first 1000 users are training set, the other 500 are test
    for filename in os.listdir(basedir + '/' + folder)[1000:]:
        if filename.endswith(".txt"):
            test_labels.append(folder)
            test_users.append(basedir + '/' + folder + '/' + filename)
        else:
            continue

print(len(users))
observations = []

#unpack list of filepaths into list of corpora
for user in users:
    #print(user)
    file = open(user, 'rb')
    x = pickle.load(file)
    corpus = ""
    for tweet in x:
        corpus += tweet
    observations.append(corpus)
    
test_corpora = []
    
for user in test_users:
    #print(user)
    file = open(user, 'rb')
    x = pickle.load(file)
    corpus = ""
    for tweet in x:
        corpus += tweet
    test_corpora.append(corpus)
    
print(len(test_corpora))
# Out:
# TXSen/BetoORourkeFollowers
# TXSen/TedCruzFollowers
# 2000
# 1000

# %%
vectorizer = TfidfVectorizer(input="content", stop_words="english", max_features=100000)#, use_idf="False")
freq_vects = vectorizer.fit_transform(observations).toarray()
test_set = vectorizer.transform(test_corpora).toarray()
print("Vectorized!")
print(freq_vects_1.shape)
# Out:
# Vectorized!
# (2000, 100000)

# %%
vectorizer_2 = TfidfVectorizer(input="content", ngram_range=(2,5), max_features=10000, stop_words="english")
freq_vects_2 = vectorizer_2.fit_transform(observations).toarray()
test_set_2 = vectorizer_2.transform(test_corpora).toarray()

freq_vects = np.block([[freq_vects, freq_vects_2]])
test_set = np.block([[test_set, test_set_2]])

print(vectorizer_2.get_feature_names())
# Out:
# ['00 pm', '000 000', '000 gaming', '000 gaming rigs', '000 gaming rigs intelrigchallenge', '000 gaming rigs intelrigchallenge originpc', '000 https', '000 jobs', '000 jobs october', '000 miles', '000 people', '000 retweets', '000 rt', '000 troops', '000 voters', '000 votes', '000 votes states', '000 year', '01 mi', '01 mi run', '026 1684', '026 1684 thanks', '0804 026', '0804 026 1684', '0804 026 1684 thanks', '08040261684 thanks', '0pwiwchgbh https', '10 00', '10 000', '10 000 gaming', '10 000 gaming rigs', '10 000 gaming rigs intelrigchallenge', '10 10', '10 12', '10 15', '10 30', '10 31', '10 9c', '10 days', '10 https', '10 minutes', '10 rt', '10 times', '10 year', '10 year old', '10 year tax', '10 years', '10 years ago', '100 000', '100 days', '100 https', '100 million', '100 years', '11 10', '11 11', '11 days', '11 https', '11 people', '11 year', '11 year old', '11 years', '12 000', '12 hours', '12 https', '12 rt', '12 year', '12 year old', '12 years', '13 https', '13 reasons', '13 year', '13 year old', '13 years', '13924598946 https', '14 year', '14 year old', '14 years', '14th amendment', '15 000', '15 https', '15 minutes', '15 rt', '15 year', '15 year old', '15 years', '15 years ago', '16 https', '16 year', '16 year old', '16 years', '1684 thanks', '17 https', '17 year', '17 year old', '17 years', '18 29', '18 29 year', '18 https', '18 months', '18 year', '18 year old', '18 years', '19 https', '19 year', '19 year old', '1k 2gb', '1k 2gb wawu', '1k 2gb wawu plan', '1k 2gb wawu plan 0804', '1st 2nd', '1st amendment', '1st day', '1st https', '1st know', '1st know means', '1st know means https', '1st line', '1st time', '1upmovement unbarredop', '1upmovement unbarredop tariqnasheed', '20 000', '20 https', '20 million', '20 minutes', '20 rt', '20 stars', '20 stars pledged', '20 stars pledged flee', '20 stars pledged flee country', '20 year', '20 years', '20 years ago', '200 000', '200 million', '2014 https', '2015 https', '2016 election', '2016 https', '2016 rt', '2016 vs', '2016 vs voting', '2016 vs voting 2018', '2017 https', '2017 rt', '2018 19', '2018 2019', '2018 exclusive', '2018 https', '2018 jodi', '2018 jodi roberts', '2018 jodi roberts kris', '2018 jodi roberts kris sands', '2018 midterm', '2018 midterms', '2018 rt', '2019 https', '202 224', '202 224 3121', '2020 https', '21 https', '21 months', '21 years', '21st century', '224 3121', '24 hours', '24 hours followers', '24 hrs', '24 hrs contact', '24 hrs contact https', '24 https', '25 hour', '25 years', '250 000', '250 000 jobs', '250 000 jobs october', '26 years', '29 year', '2gb 08040261684', '2gb 08040261684 thanks', '2gb wawu', '2gb wawu plan', '2gb wawu plan 0804', '2gb wawu plan 0804 026', '2nd amendment', '30 000', '30 days', '30 https', '30 million', '30 million russia', '30 million russia used', '30 million russia used nra', '30 minute', '30 minutes', '30 pm', '30 rt', '30 seconds', '30 years', '300 000', '35 years', '3scoutmom realronhoward', '40 000', '40 approval', '40 approval rating', '40 approval rating african', '40 approval rating african americans', '40 years', '400 000', '48 hours', '4th july', '50 000', '50 https', '50 years', '500 000', '5100 missing', '5100 missing murdered', '5100 missing murdered indigenous', '53 000', '60 minutes', '60 years', '6th vote', '70 000', '7am 7pm', '7elhj5td8k master', '7elhj5td8k master hr', '7elhj5td8k master hr mba', '7elhj5td8k master hr mba real', '832 233', '832 233 7760', '86 13924598946', '86 13924598946 https', '8yearsofonedirectionrt onedirection', '90 grades', '90 grades 90', '90 grades 90 grades', '90 grades 90 grades 90', '97 year', '97 year old', '99 https', '__ gt', '__ gt want', '__ gt want __', '__ gt want __ lt', '__ lt', '_jenniferlong jason_howerton', '_sjpeace_ parents', '_sjpeace_ parents told', '_sjpeace_ parents told time', '_sjpeace_ parents told time bye', 'aaron rodgers', 'ab rt', 'abc news', 'abducted adopted', 'able https', 'able make', 'abo rt', 'abolish ice', 'abortion https', 'abou ...

# %%
NBclf = GaussianNB().fit(freq_vects, labels)
#print(vectorizer.get_feature_names())
print("Trained!")
# Out:
# Trained!

# %%
predicted = NBclf.predict(test_set)
np.mean(predicted == test_labels)
# Out:
# 0.818
